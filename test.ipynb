# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songsplays limit 3;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 3 rows affected.
# [(1, datetime.datetime(2018, 11, 9, 0, 6, 17, 796000), 42, 'SONWXQJ12A8C134D94', 'ARNF6401187FB57032', 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (2, datetime.datetime(2018, 11, 9, 0, 9, 46, 796000), 42, 'SONWXQJ12A8C134D94', 'ARNF6401187FB57032', 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (3, datetime.datetime(2018, 11, 9, 0, 12, 27, 796000), 42, 'SONWXQJ12A8C134D94', 'ARNF6401187FB57032', 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')]

# %%
# %sql SELECT *FROM users  limit 2  ;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 2 rows affected.
# [(26, 'Ryan', 'Smith', 'M', 'free'), (73, 'Jacob', 'Klein', 'M', 'paid')]

# %%
# %sql SELECT * FROM songs limit 3 ;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 3 rows affected.
# [('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 1994, 305.162),
#  ('SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 0, 152.92036),
#  ('SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 0, 279.97995)]

# %%
# %sql SELECT * FROM artists limit 4 ;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 4 rows affected.
# [('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', 40.79086, -73.96644),
#  ('ARJIE2Y1187B994AB7', 'Line Renaud', '', nan, nan),
#  ('ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', 41.88415, -87.63241),
#  ('AR558FS1187FB45658', '40 Grit', '', nan, nan)]

# %%
# %sql SELECT  * FROM tiempo limit 4 ;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 4 rows affected.
# [(datetime.datetime(2018, 11, 9, 0, 6, 17, 796000), 0, 9, 45, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 9, 0, 9, 46, 796000), 0, 9, 45, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 9, 0, 12, 27, 796000), 0, 9, 45, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 9, 0, 14, 52, 796000), 0, 9, 45, 11, 2018, 4)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql SELECT u.user_id, coalesce(u.first_name||' '||u.last_name) as nombrecompleto, level FROM songsplays s inner join users u on s.user_id= u.user_id group by u.user_id, level, coalesce(u.first_name||' '||u.last_name);
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 96 rows affected.
# [(64, 'Hannah Calhoun', 'free'),
#  (44, 'Aleena Kirby', 'paid'),
#  (65, 'Amiya Davidson', 'paid'),
#  (63, 'Ayla Johnson', 'free'),
#  (30, 'Avery Watkins', 'paid'),
#  (47, 'Kimber Norris', 'free'),
#  (83, 'Stefany White', 'free'),
#  (95, 'Sara Johnson', 'paid'),
#  (37, 'Jordan Hicks', 'free'),
#  (6, 'Cecilia Owens', 'free'),
#  (34, 'Evelin Ayala', 'free'),
#  (41, 'Brayden Clark', 'free'),
#  (99, 'Ann Banks', 'free'),
#  (69, 'Anabelle Simpson', 'free'),
#  (35, 'Molly Taylor', 'free'),
#  (76, 'Jayden Duffy', 'free'),
#  (8, 'Kaylee Summers', 'free'),
#  (87, 'Dustin Lee', 'free'),
#  (82, 'Avery Martinez', 'paid'),
#  (85, 'Kinsley Young', 'paid'),
#  (18, 'Jacob Rogers', 'free'),
#  (52, 'Theodore Smith', 'free'),
#  (49, 'Chloe Cuevas', 'paid'),
#  (86, 'Aiden Hess', 'free'),
#  (9, 'Wyatt Scott', 'free'),
#  (73, 'Jacob Klein', 'paid'),
#  (54, 'Kaleb Cook', 'free'),
# ...
